# %% [markdown]
# <a href="https://colab.research.google.com/github/azholl/lis5693/blob/main/lab_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests

# %%
import requests
import os
import json

# %%
SERPAPI_API_KEY = "api-key"

# %%
params = {
    "api_key": SERPAPI_API_KEY,
    "engine": "youtube_video_transcript",
    "v": "KmL7qrpy19Q",
    "type": "asr"
}

# %%
search = requests.get("https://serpapi.com/search", params=params)
response = search.json()

print(json.dumps(response, indent=2))
# Out:
# {
#   "search_metadata": {
#     "id": "698f715e17bdbff893d70850",
#     "status": "Success",
#     "json_endpoint": "https://serpapi.com/searches/EsmMTCQ7wYIt8vHOG7ggzg/698f715e17bdbff893d70850.json",
#     "created_at": "2026-02-13 18:45:50 UTC",
#     "processed_at": "2026-02-13 18:45:50 UTC",
#     "youtube_video_transcript_url": "https://www.youtube.com/watch?v=KmL7qrpy19Q",
#     "raw_html_file": "https://serpapi.com/searches/EsmMTCQ7wYIt8vHOG7ggzg/698f715e17bdbff893d70850.html",
#     "prettify_html_file": "https://serpapi.com/searches/EsmMTCQ7wYIt8vHOG7ggzg/698f715e17bdbff893d70850.prettify",
#     "total_time_taken": 20.06
#   },
#   "search_parameters": {
#     "engine": "youtube_video_transcript",
#     "v": "KmL7qrpy19Q",
#     "language_code": "en",
#     "type": "asr"
#   },
#   "transcript": [
#     {
#       "start_ms": 80,
#       "end_ms": 6160,
# ...

# %%
for result in response.get("transcript", []):
    snippet = result.get("snippet")
    start_time_text = result.get("start_time_text")

    print(f"SnippetL: {snippet}")
    print(f"Start Time: {start_time_text}")
    print("-" * 10)
# Out:
# SnippetL: Hey everybody, welcome to the next commentary. Today we're playing some Mel mid into a Yona. Uh Mel got changed
# Start Time: 0:00
# ----------
# SnippetL: recently with her W reflect like losing the invulnerability and a lot of other changes too. And her win rate dropped so
# Start Time: 0:06
# ----------
# SnippetL: hard to the point that she got hot fixed. So she did get buffed already because hot fix is like a live patch
# Start Time: 0:12
# ----------
# SnippetL: basically. But I have played her and she is kind of strange now with her Q because it feels
# Start Time: 0:18
# ----------
# SnippetL: as though it's much harder to land but the damage from it is like slightly better. Uh, it comes out so freaking
# Start Time: 0:24
# ----------
# SnippetL: fast. Like it shoots all of the little orbs so quickly and if you land all of them, I think that the AP ratio was like
# Start Time: 0:31
# ----------
# ...

# %%
with open('transcript.txt', 'w') as f:
    for result in response.get("transcript", []):
        snippet = result.get("snippet")
        if snippet:
            f.write(f"{snippet}\n")

print("Results saved to transcript.txt")
# Out:
# Results saved to transcript.txt

# %% [markdown]
# Getting the transcript for the YouTube video and downloading it on my device was relatively easy with the clear instructions that were provided. Actually grabbing the transcript and parsing it down to make it cleaner went well. There were a few errors I got when I first started running code cells related to the name of my API key I was trying to assign as a variable. I just looked up "Python variable name error google colab" in my search engine and was able to find a Google colab file that quickly goes over allowed variable names. This allowed me to fix my problem (I didn't put "" around the variable) easily, although I did feel a bit silly for not catching the error myself. I had some issues creating the lab 1 folder in my github repository and uploading the transcript to it. I had to read a couple of comments on different forums and some basic webpages to understand. I also ended up asking my coworker and friend who went through Atlas school in Tulsa about Github and she was able to give me a few pointers that I would have spent a lot longer figuring out on my own if I wasn't able to ask her.
